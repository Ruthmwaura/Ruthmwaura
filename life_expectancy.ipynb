# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruthmwaura/Ruthmwaura/blob/main/life_expectancy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LIFE EXPECTANCY DATA ANALYSIS
#
# ##1. Defining the question
#
# a) Specifying the Data Analytic Question
#
#
#
#
# b) Defining the Metric for Success
#
#
#
#
#
# c) Understanding the context
#
#
#
#
#
# d) Recording the Experimental Design
#
# To successfully conduct this project the following steps will be taken in order:

# %% [markdown]
# ##2.Data Loading and Understanding

# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
#loading data to the enviroment
expectancy=pd.read_csv('/content/Life Expectancy Data.csv')
expectancy.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
#previewing the number of columns and rows
print("The dataframe has "  +  str(expectancy.shape[1])   +   " columns and " + str(expectancy.shape[0])  +   " rows.")
# Out:
# The dataframe has 22 columns and 2938 rows.

# %%
#listing the columns
expectancy.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
#checking the data types and non-null values
expectancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %% [markdown]
# We have null value entries in some columns.
#
# All columns are in the right data type.

# %% [markdown]
# ##3.Data Cleaning

# %% [markdown]
# ###a)Validity

# %% [markdown]
# All columns are Relevant

# %% [markdown]
# ###b)Completeness

# %%
#Checking if there is any missing value across each column
print(expectancy.isna().sum())
print(expectancy.isnull().sum().sum())
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64
# 2563

# %% [markdown]
# Most columns have missing values.
#
# Total number of missing values is 2165.

# %%
#filling null values in the life expectancy column
#checking the missing values by Country
expectancy[expectancy['Life expectancy '].isnull()].Year
# Out:
# 624     2013
# 769     2013
# 1650    2013
# 1715    2013
# 1812    2013
# 1909    2013
# 1958    2013
# 2167    2013
# 2216    2013
# 2713    2013
# Name: Year, dtype: int64

# %% [markdown]
# ###c)Consistency

# %%
#checking for duplicates
expectancy.duplicated().any().any()
# Out:
# False

# %% [markdown]
# there were no duplicates

# %% [markdown]
# ###d)Uniformity

# %%
#renaming columns for uniformity
#we will start by replacing the ' ' with '_'
expectancy.columns = expectancy.columns.astype(str).str.replace(" ", "_")
expectancy.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy_', 'Adult_Mortality',
#        'infant_deaths', 'Alcohol', 'percentage_expenditure', 'Hepatitis_B',
#        'Measles_', '_BMI_', 'under-five_deaths_', 'Polio', 'Total_expenditure',
#        'Diphtheria_', '_HIV/AIDS', 'GDP', 'Population',
#        '_thinness__1-19_years', '_thinness_5-9_years',
#        'Income_composition_of_resources', 'Schooling'],
#       dtype='object')

# %%
#removing the unneccesary '_'
expectancy.rename(columns={'Life_expectancy_':'Life_expectancy','Measles_':'Measles','_BMI_':'BMI','Diphtheria_':'Diphtheria',
                   '_HIV/AIDS':'HIV/AIDS','_thinness__1-19_years':'thinness__1-19_years','_thinness_5-9_years':'thinness_5-9_years'},inplace=True)
expectancy.head()
# Out:
#        Country  Year      Status  Life_expectancy  Adult_Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant_deaths  Alcohol  percentage_expenditure  Hepatitis_B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total_expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
#changing all names to lowercase
expectancy.columns= expectancy.columns.str.lower()
expectancy.head()
# Out:
#        country  year      status  life_expectancy  adult_mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant_deaths  alcohol  percentage_expenditure  hepatitis_b  measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    polio  total_expenditure  diphtheria  hiv/aids         gdp  population  \
# ...

# %% [markdown]
# ###e)Outliers

# %%
#finding outliers

numerical_data= expectancy.select_dtypes(exclude='object')

Q1 = numerical_data.quantile(0.25)
Q3 = numerical_data.quantile(0.75)
IQR = Q3 - Q1

(numerical_data < (Q1 - 1.5 * IQR)) |(numerical_data > (Q3 + 1.5 * IQR))
# Out:
#        year  life_expectancy  adult_mortality  infant_deaths  alcohol  \
# 0     False            False            False           True    False
# 1     False            False            False           True    False
# 2     False            False            False           True    False
# 3     False            False            False           True    False
# 4     False            False            False           True    False
# ...     ...              ...              ...            ...      ...
# 2933  False            False             True          False    False
# 2934  False            False             True          False    False
# 2935  False            False            False          False    False
# 2936  False            False             True          False    False
# 2937  False            False             True          False    False
#
#       percentage_expenditure  hepatitis_b  measles    bmi  under-five_deaths_  \
# ...

# %% [markdown]
# We have outliers in our dataset.
